# %%
import pandas as pd
from nltk.tokenize import RegexpTokenizer
import re
import numpy as np
from collections import defaultdict
import pandas as pd
from bs4 import BeautifulSoup
import requests
import os
import PyPDF2
import fitz
import re

# %%
approvals = list(pd.read_csv('aiml_list.csv')['0'].values)

# %%
# Feature name mapping for HTML
mapping = {'Device Classification Name': 'device_classification_name',
          '510(k) Number': 'approval_number',
           'De Novo Number': 'approval_number',
          'Device Name': 'device_name',
          'Applicant': 'applicant_name',
           'Requester': 'applicant_name',
          'Applicant Contact': 'applicant_contact',
          'Correspondent': 'correspondent_name',
          'Regulation Number': 'regulation_number',
          'Classification Product Code': 'classification_product_code',
          'Date Received': 'date_received',
          'Decision Date': 'decision_date',
           'Decision': 'decision',
           'Classification Advisory Committee': 'classification_advisory',
           'Review Advisory Committee': 'review_advisory',
           'Regulation Medical Specialty': 'regulation_medical_specialty',
           '510k Review Panel': 'review_panel',
           'statement': 'summary_link',
           'summary': 'summary_link',
           'FDA Review': 'summary_link',
           'Reclassification Order': 'reclass_link',
           'Type': 'type',
           'Reviewed by Third Party': 'reviewed_by_third_party',
           'Combination Product': 'combination_product'
          }

# %%
entries = []

for approval in approvals:

    # Parse metadata from FDA website
    with open('FDA_htmls/{}.html'.format(approval), 'r') as fp:
        soup = BeautifulSoup(fp)
    entry = {}
    entry['query_id'] = approval
    for table in soup.findAll('table', {'align': 'center', 'style': 'text-transform: capitalize'}):
        for tr in table.findAll('tr'):
            try:
                th = tr.find('th').text
            except:
                continue

            for k, v in mapping.items():
                if k in th:
                    if v == 'summary_link':
                        link = tr.find('a', href=True)['href']
                        if len(link) == 0:
                            link = tr.find('A', href=True)['HREF']
                        entry[v] = link.strip().lower().replace('\n', ' ').replace('\r', ' ').replace('\t', ' ')
                    else:
                        text = tr.find('td').text
                        if len(text) > 0:
                            entry[v] = text.strip().lower().replace('\n', ' ').replace('\r', ' ').replace('\t', ' ')
    if len(entry) > 0:                    
        entries.append(entry)
    else:
        raise ValueError('No values found for HTML file {}'.format(approval))
        
df = pd.DataFrame(entries)

# %%
df
# Out:
#     query_id                         device_classification_name  \
# 0    K181502                 computer, diagnostic, programmable
# 1    K193087  radiological computer-assisted triage and noti...
# 2    K192854  radiological computer assisted detection/diagn...
# 3    K180647  radiological computer-assisted triage and noti...
# 4    K192065      system, planning, radiation therapy treatment
# ..       ...                                                ...
# 130  K191278             system, image processing, radiological
# 131  K200743        system, imaging, pulsed doppler, ultrasonic
# 132  K192973             system, image processing, radiological
# 133  K182875  radiological computer-assisted triage and noti...
# 134  K200132             system, image processing, radiological
#
#     approval_number                                device_name  \
# 0           k181502  zio at ecg monitoring system, zeus system
# 1           k193087                                  rapid ich
# 2           k192854                                mammoscreen
# 3           k180647                                  briefcase
# 4           k192065                   syngo.via rt image suite
# ..              ...                                        ...
# 130         k191278                                   rsi-mri+
# 131         k200743            vivid e80/ vivid e90/ vivid e95
# 132         k192973                         densitas densityai
# 133         k182875                                     deepct
# 134         k200132                                    ashvins
#
#          applicant_name   applicant_contact  correspondent_name  \
# 0          rich  laguna        rich  laguna        rich  laguna
# 1           james  rosa         james  rosa         james  rosa
# 2    quentin  de snoeck  quentin  de snoeck      cindy  domecus
# 3       nimrod  epstein     nimrod  epstein       john j. smith
# 4    veronica  padharia  veronica  padharia  veronica  padharia
# ..                  ...                 ...                 ...
# 130   stephen  kosnosky   stephen  kosnosky   stephen  kosnosky
# 131       tracey  ortiz       tracey  ortiz       tracey  ortiz
# 132        mo  abdolell        mo  abdolell        alex  morris
# 133        william  lai        william  lai        william  lai
# 134  martin  schinkmann  martin  schinkmann       lena  sattler
#
#     regulation_number classification_product_code date_received  ...  \
# 0            870.1425                         dqk    06/07/2018  ...
# 1            892.2080                         qas    11/06/2019  ...
# 2            892.2090                         qdq    10/04/2019  ...
# 3            892.2080                         qas    03/12/2018  ...
# 4            892.5050                         muj    08/01/2019  ...
# ..                ...                         ...           ...  ...
# 130          892.2050                         llz    05/13/2019  ...
# 131          892.1550                         iyn    03/23/2020  ...
# 132          892.2050                         llz    10/24/2019  ...
# 133          892.2080                         qas    10/12/2018  ...
# 134          892.2050                         llz    01/21/2020  ...
#
#                                 decision regulation_medical_specialty  \
# 0    substantially equivalent     (sese)               cardiovascular
# 1    substantially equivalent     (sese)                    radiology
# 2    substantially equivalent     (sese)                    radiology
# 3    substantially equivalent     (sese)                    radiology
# 4    substantially equivalent     (sese)                    radiology
# ..                                   ...                          ...
# 130  substantially equivalent     (sese)                    radiology
# 131  substantially equivalent     (sese)                    radiology
# 132  substantially equivalent     (sese)                    radiology
# 133  substantially equivalent     (sese)                    radiology
# 134  substantially equivalent     (sese)                    radiology
#
#        review_panel                                       summary_link  \
# 0    cardiovascular  http://www.accessdata.fda.gov/cdrh_docs/pdf18/...
# 1         radiology  http://www.accessdata.fda.gov/cdrh_docs/pdf19/...
# 2         radiology  http://www.accessdata.fda.gov/cdrh_docs/pdf19/...
# 3         radiology  http://www.accessdata.fda.gov/cdrh_docs/pdf18/...
# 4         radiology  http://www.accessdata.fda.gov/cdrh_docs/pdf19/...
# ..              ...                                                ...
# 130       radiology  http://www.accessdata.fda.gov/cdrh_docs/pdf19/...
# 131       radiology  http://www.accessdata.fda.gov/cdrh_docs/pdf20/...
# 132       radiology  http://www.accessdata.fda.gov/cdrh_docs/pdf19/...
# 133       radiology  http://www.accessdata.fda.gov/cdrh_docs/pdf18/...
# 134       radiology  http://www.accessdata.fda.gov/cdrh_docs/pdf20/...
#
#             type reviewed_by_third_party combination_product  \
# 0    traditional                      no                  no
# 1    traditional                      no                  no
# 2    traditional                      no                  no
# 3    traditional                      no                  no
# 4    traditional                      no                  no
# ..           ...                     ...                 ...
# 130  traditional                      no                  no
# 131  traditional                      no                  no
# 132      special                      no                  no
# 133  traditional                      no                  no
# 134  traditional                      no                  no
#
#     classification_advisory review_advisory reclass_link
# 0                       NaN             NaN          NaN
# 1                       NaN             NaN          NaN
# 2                       NaN             NaN          NaN
# 3                       NaN             NaN          NaN
# 4                       NaN             NaN          NaN
# ..                      ...             ...          ...
# 130                     NaN             NaN          NaN
# 131                     NaN             NaN          NaN
# 132                     NaN             NaN          NaN
# 133                     NaN             NaN          NaN
# 134                     NaN             NaN          NaN
#
# [135 rows x 21 columns]

# %%
df.to_csv('aiml_metadata_df.csv', index=False)
